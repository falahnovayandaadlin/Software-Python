# %%
! pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca data
pariwisata_jabar = pd.read_excel("data set paraiwisata jabar.xlsx")
pariwisata_jabar
# Out:
#         nama_kabupaten_kota  \
# 0         KABUPATEN BANDUNG
# 1   KABUPATEN BANDUNG BARAT
# 2          KABUPATEN BEKASI
# 3           KABUPATEN BOGOR
# 4          KABUPATEN CIAMIS
# 5         KABUPATEN CIANJUR
# 6         KABUPATEN CIREBON
# 7           KABUPATEN GARUT
# 8       KABUPATEN INDRAMAYU
# 9        KABUPATEN KARAWANG
# 10       KABUPATEN KUNINGAN
# 11     KABUPATEN MAJALENGKA
# 12    KABUPATEN PANGANDARAN
# 13     KABUPATEN PURWAKARTA
# 14         KABUPATEN SUBANG
# 15       KABUPATEN SUKABUMI
# 16       KABUPATEN SUMEDANG
# 17    KABUPATEN TASIKMALAYA
# 18             KOTA BANDUNG
# 19              KOTA BANJAR
# 20              KOTA BEKASI
# 21               KOTA BOGOR
# 22              KOTA CIMAHI
# 23             KOTA CIREBON
# 24               KOTA DEPOK
# 25            KOTA SUKABUMI
# 26         KOTA TASIKMALAYA
#
#     jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 0                                             1577118
# ...

# %%
# menampilkan data
pariwisata_jabar.tail()
# Out:
#    nama_kabupaten_kota  jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 22         KOTA CIMAHI                                               1699
# 23        KOTA CIREBON                                               6203
# 24          KOTA DEPOK                                              24167
# 25       KOTA SUKABUMI                                              10468
# 26    KOTA TASIKMALAYA                                             267156
#
#     jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# 22                                             80367
# 23                                           8065781
# 24                                           5872941
# 25                                            622235
# 26                                           1761910
#
#     jumlah_pengunjung _Kolam Renang_Mancanegara (X3)  \
# 22                                                 8
# 23                                                 0
# ...

# %%
# melihat informasi data frame
pariwisata_jabar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   nama_kabupaten_kota                                    27 non-null     object
#  1   jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)     27 non-null     int64
#  2   jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)       27 non-null     int64
#  3   jumlah_pengunjung _Kolam Renang_Mancanegara (X3)       27 non-null     int64
#  4   jumlah_pengunjung _Kolam Renang_Nusantara (X4)         27 non-null     int64
#  5   jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)  27 non-null     int64
#  6   jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)    27 non-null     int64
#  7   kasus_aktif_jabar (X7)                                 27 non-null     int64
# dtypes: int64(7), object(1)
# ...

# %%
# melihat ada NA
pariwisata_jabar.isnull().any()
# Out:
# nama_kabupaten_kota                                      False
# jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)       False
# jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)         False
# jumlah_pengunjung _Kolam Renang_Mancanegara (X3)         False
# jumlah_pengunjung _Kolam Renang_Nusantara (X4)           False
# jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)    False
# jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)      False
# kasus_aktif_jabar (X7)                                   False
# dtype: bool

# %%
# melihat jumlah NA
pariwisata_jabar.isnull().sum()
# Out:
# nama_kabupaten_kota                                      0
# jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)       0
# jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)         0
# jumlah_pengunjung _Kolam Renang_Mancanegara (X3)         0
# jumlah_pengunjung _Kolam Renang_Nusantara (X4)           0
# jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)    0
# jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)      0
# kasus_aktif_jabar (X7)                                   0
# dtype: int64

# %%
# boxplot
pariwisata_jabar['jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)'].plot(kind='box');

# %%
pariwisata_jabar['jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)'].plot(kind='box');

# %%
pariwisata_jabar['jumlah_pengunjung _Kolam Renang_Mancanegara (X3)'].plot(kind='box');

# %%
pariwisata_jabar['jumlah_pengunjung _Kolam Renang_Nusantara (X4)'].plot(kind='box');

# %%
pariwisata_jabar['jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)'].plot(kind='box');

# %%
pariwisata_jabar['jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)'].plot(kind='box');

# %%
pariwisata_jabar['kasus_aktif_jabar (X7)'].plot(kind='box');

# %%
sns.barplot(x ="jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="jumlah_pengunjung _Kolam Renang_Mancanegara (X3)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung _Kolam Renang_Mancanegara (X3)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="jumlah_pengunjung _Kolam Renang_Nusantara (X4)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung _Kolam Renang_Nusantara (X4)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)', ylabel='nama_kabupaten_kota'>

# %%
sns.barplot(x ="kasus_aktif_jabar (X7)", y="nama_kabupaten_kota", data=pariwisata_jabar)
# Out:
# <AxesSubplot:xlabel='kasus_aktif_jabar (X7)', ylabel='nama_kabupaten_kota'>

# %%
pariwisata_jabar.shape
# Out:
# (27, 8)

# %%
# menentukan variable yang akan di-clustering
x = pariwisata_jabar.iloc[:, 1:8]
x
# Out:
#     jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 0                                             1577118
# 1                                             1438382
# 2                                                   3
# 3                                             1216875
# 4                                                6607
# 5                                              509351
# 6                                                  15
# 7                                               21964
# 8                                                  59
# 9                                                2372
# 10                                               1107
# 11                                               3058
# 12                                              31780
# 13                                             440020
# 14                                            1095227
# 15                                             175049
# ...

# %%
# mengubah data menjadi array
x_array = np.array(x)
x_array
# Out:
# array([[ 1577118, 25792956,        0,   169529,  3440529,    23431,
#            57868],
#        [ 1438382, 27734199,        0,        0,  1270937,     3089,
#            20765],
#        [       3,   383413,        0,        0,   127500,        0,
#           150222],
#        [ 1216875, 24644931,        0,        0,    28376,        0,
#            86376],
#        [    6607,  4371123,        0,   255268,   616643,        2,
#             8367],
#        [  509351, 18033510,        0,        0,  1041740,    29461,
#             4453],
#        [      15,  3841479,        0,     3850,   352426,        0,
#            31225],
#        [   21964, 13922197,        0,        0,  1907007,       94,
#            33398],
#        [      59,  3856787,        0,    51055,   210344,       22,
#            11353],
#        [    2372, 32719357,      728,    32168,  1426983,       92,
#            77039],
#        [    1107,  6992790,        0,        0,  1270547,       27,
# ...

# %%
# scaling data
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
# Menstandarkan ukuran (scaling)
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x_array)

# %% [markdown]
# Jumlah Cluster: elbow method(wss)

# %%
# function returns WSS score for k values from 1 to kmax
def calculate_WSS(points, kmax):
  sse = []
  for k in range(1, kmax+1):
    kmeans = KMeans(n_clusters = k).fit(points)
    centroids = kmeans.cluster_centers_
    pred_clusters = kmeans.predict(points)
    curr_sse = 0
    
    # calculate square of Euclidean distance of each point from its cluster center and add to current WSS
    for i in range(len(points)):
      curr_center = centroids[pred_clusters[i]]
      curr_sse += (points[i, 0] - curr_center[0]) ** 2 + (points[i, 1] - curr_center[1]) ** 2
      
    sse.append(curr_sse)
  return sse

# %%
wss = calculate_WSS(x_scaled, 15)
wss
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [4.922294751962049,
#  1.9929369274639042,
#  1.3455217547599259,
#  1.499561409730353,
#  1.2089890791983635,
#  1.1461564891315619,
#  0.8242707783010423,
#  0.6134859320249488,
#  0.517784892454537,
#  0.38870330879540443,
#  0.2735325747918394,
#  0.18506194973767537,
#  0.17868704304368718,
#  0.13487598591597105,
#  0.08206387253885974]

# %%
# K-cluster wss
xx = np.arange(1, 16, 1)
plt.figure(figsize=[7,7])
plt.plot(xx, wss,"b-o")
plt.show()

# %% [markdown]
# Jumlah Cluster: K-cluster Silhote

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np


range_n_clusters = [2, 3, 4, 5, 6]

def silh(X):
    for n_clusters in range_n_clusters:
        # Create a subplot with 1 row and 2 columns
        fig, (ax1, ax2) = plt.subplots(1, 2)
        fig.set_size_inches(18, 7)

        # The 1st subplot is the silhouette plot
        # The silhouette coefficient can range from -1, 1 but in this example all
        # lie within [-0.1, 1]
        ax1.set_xlim([-0.1, 1])
        # The (n_clusters+1)*10 is for inserting blank space between silhouette
        # plots of individual clusters, to demarcate them clearly.
        ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

        # Initialize the clusterer with n_clusters value and a random generator
        # seed of 10 for reproducibility.
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(X)

        # The silhouette_score gives the average value for all the samples.
        # This gives a perspective into the density and separation of the formed
        # clusters
        silhouette_avg = silhouette_score(X, cluster_labels)
        print(
            "For n_clusters =",
            n_clusters,
            "The average silhouette_score is :",
            silhouette_avg,
        )

        # Compute the silhouette scores for each sample
        sample_silhouette_values = silhouette_samples(X, cluster_labels)

        y_lower = 10
        for i in range(n_clusters):
            # Aggregate the silhouette scores for samples belonging to
            # cluster i, and sort them
            ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

            ith_cluster_silhouette_values.sort()

            size_cluster_i = ith_cluster_silhouette_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_clusters)
            ax1.fill_betweenx(
                np.arange(y_lower, y_upper),
                0,
                ith_cluster_silhouette_values,
                facecolor=color,
                edgecolor=color,
                alpha=0.7,
            )

            # Label the silhouette plots with their cluster numbers at the middle
            ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

            # Compute the new y_lower for next plot
            y_lower = y_upper + 10  # 10 for the 0 samples

        ax1.set_title("The silhouette plot for the various clusters.")
        ax1.set_xlabel("The silhouette coefficient values")
        ax1.set_ylabel("Cluster label")

        # The vertical line for average silhouette score of all the values
        ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

        ax1.set_yticks([])  # Clear the yaxis labels / ticks
        ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

        # 2nd Plot showing the actual clusters formed
        colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
        ax2.scatter(
            X[:, 0], X[:, 1], marker="o", s=50, lw=0, alpha=0.7, c=colors, edgecolor="k"
        )

        # Labeling the clusters
        centers = clusterer.cluster_centers_
        # Draw white circles at cluster centers
        ax2.scatter(
            centers[:, 0],
            centers[:, 1],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

        ax2.set_title("The visualization of the clustered data.")
        ax2.set_xlabel("Feature space for the 1st feature")
        ax2.set_ylabel("Feature space for the 2nd feature")

        plt.suptitle(
            "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
            % n_clusters,
            fontsize=14,
            fontweight="bold",
        )

    plt.show()

# %%
silh(x_scaled)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.36946436785994186
# For n_clusters = 3 The average silhouette_score is : 0.40091060782300286
# For n_clusters = 4 The average silhouette_score is : 0.3948938863890265
# For n_clusters = 5 The average silhouette_score is : 0.42376096822187287
# For n_clusters = 6 The average silhouette_score is : 0.4807150420047001

# %% [markdown]
# ## Proses Cluster

# %%
x_scaled
# Out:
# array([[1.00000000e+00, 7.88036261e-01, 0.00000000e+00, 5.18437309e-01,
#         8.72915352e-01, 6.81133721e-01, 2.34587855e-01],
#        [9.12031780e-01, 8.47442744e-01, 0.00000000e+00, 0.00000000e+00,
#         3.20878794e-01, 8.97965116e-02, 7.59426016e-02],
#        [0.00000000e+00, 1.04460308e-02, 0.00000000e+00, 0.00000000e+00,
#         2.99397480e-02, 0.00000000e+00, 6.29475701e-01],
#        [7.71581020e-01, 7.52904066e-01, 0.00000000e+00, 0.00000000e+00,
#         4.71838297e-03, 0.00000000e+00, 3.56482550e-01],
#        [4.18739280e-03, 1.32479093e-01, 0.00000000e+00, 7.80636086e-01,
#         1.54398549e-01, 5.81395349e-05, 2.29311510e-02],
#        [3.22961864e-01, 5.50579436e-01, 0.00000000e+00, 0.00000000e+00,
#         2.62561321e-01, 8.56424419e-01, 6.19564381e-03],
#        [7.60883005e-06, 1.16270773e-01, 0.00000000e+00, 1.17737003e-02,
#         8.71704969e-02, 0.00000000e+00, 1.20667539e-01],
# ...

# %%
pip install scikit-learn-extra
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn_extra.cluster import KMedoids
import numpy as np

# %%
KMedoids?
# Out:
# Init signature:
# KMedoids(
#     n_clusters=8,
#     metric='euclidean',
#     method='alternate',
#     init='heuristic',
#     max_iter=300,
#     random_state=None,
# )
# Docstring:
# k-medoids clustering.
#
# Read more in the :ref:`User Guide <k_medoids>`.
#
# Parameters
# ----------
# n_clusters : int, optional, default: 8
#     The number of clusters to form as well as the number of medoids to
#     generate.
#
# metric : string, or callable, optional, default: 'euclidean'
#     What distance metric to use. See :func:metrics.pairwise_distances
#     metric can be 'precomputed', the user must then feed the fit method
#     with a precomputed kernel matrix and not the design matrix X.
#
# method : {'alternate', 'pam'}, default: 'alternate'
#     Which algorithm to use. 'alternate' is faster while 'pam' is more accurate.
#
# init : {'random', 'heuristic', 'k-medoids++', 'build'}, optional, default: 'build'
#     Specify medoid initialization method. 'random' selects n_clusters
# ...

# %%
# Menentukan model kmedoids cara 1
kmedoids_jabar = KMedoids(n_clusters=3, random_state=123).fit(x_scaled)

# %%
# Menentukan model kmedoids cara 2
kmedoids_jabar = KMedoids(
    n_clusters=3,
    metric='euclidean',
    method='alternate',
    init='heuristic',
    max_iter=300,
    random_state=123,
)

# %%
# Menginputkan data
kmedoids_jabar.fit(x_scaled)
# Out:
# KMedoids(n_clusters=3, random_state=123)

# %%
kmedoids_jabar.get_params
# Out:
# <bound method BaseEstimator.get_params of KMedoids(n_clusters=3, random_state=123)>

# %%
# Menampilkan label cluster
kmedoids_jabar.labels_
# Out:
# array([0, 0, 2, 0, 1, 0, 2, 1, 1, 1, 1, 2, 1, 0, 0, 1, 1, 1, 0, 2, 2, 0,
#        2, 1, 2, 2, 2], dtype=int64)

# %%
# menampilkan pusat cluster
kmedoids_jabar.cluster_centers_
# Out:
# array([[0.69444777, 0.46701973, 0.        , 0.16375229, 0.07662411,
#         0.03156977, 0.03205572],
#        [0.01037718, 0.19924913, 0.        , 0.08510398, 0.16496479,
#         0.00389535, 0.01567938],
#        [0.00107538, 0.00117213, 0.00603318, 0.08202141, 0.00974922,
#         0.00084302, 0.16113805]])

# %%
# menambahkan kolom cluster ke data frame pariwisata jabar
pariwisata_jabar['cluster'] = kmedoids_jabar.labels_
pariwisata_jabar.head()
# Out:
#        nama_kabupaten_kota  \
# 0        KABUPATEN BANDUNG
# 1  KABUPATEN BANDUNG BARAT
# 2         KABUPATEN BEKASI
# 3          KABUPATEN BOGOR
# 4         KABUPATEN CIAMIS
#
#    jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 0                                            1577118
# 1                                            1438382
# 2                                                  3
# 3                                            1216875
# 4                                               6607
#
#    jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# 0                                          25792956
# 1                                          27734199
# 2                                            383413
# 3                                          24644931
# 4                                           4371123
#
#    jumlah_pengunjung _Kolam Renang_Mancanegara (X3)  \
# 0                                                 0
# ...

# %%
pariwisata_jabar['cluster'] = kmedoids_jabar.labels_

# %%
pariwisata_jabar.to_csv('klustering_pariwisata_jabar.csv')

# %% [markdown]
# ## Profilisasi

# %%
# Membentuk berdasarkan kolom cluster
grup=pariwisata_jabar.groupby('cluster')

# %%
profil = pd.DataFrame(grup.mean())
profil
# Out:
#          jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# cluster
# 0                                            959958.875000
# 1                                             30025.000000
# 2                                             34069.777778
#
#          jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# cluster
# 0                                            2.106584e+07
# 1                                            1.026083e+07
# 2                                            1.667593e+06
#
#          jumlah_pengunjung _Kolam Renang_Mancanegara (X3)  \
# cluster
# 0                                               10.250000
# 1                                              205.400000
# 2                                               70.888889
#
#          jumlah_pengunjung _Kolam Renang_Nusantara (X4)  \
# cluster
# 0                                          68879.500000
# 1                                          38775.200000
# ...

# %%
profil['cluster'] = profil.index

# %%
profil
# Out:
#          jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# cluster
# 0                                            959958.875000
# 1                                             30025.000000
# 2                                             34069.777778
#
#          jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# cluster
# 0                                            2.106584e+07
# 1                                            1.026083e+07
# 2                                            1.667593e+06
#
#          jumlah_pengunjung _Kolam Renang_Mancanegara (X3)  \
# cluster
# 0                                               10.250000
# 1                                              205.400000
# 2                                               70.888889
#
#          jumlah_pengunjung _Kolam Renang_Nusantara (X4)  \
# cluster
# 0                                          68879.500000
# 1                                          38775.200000
# ...

# %%
profil.to_csv('profilisasi_pariwisata_jabar.csv')

# %%
profil.plot(x = 'cluster', y = ['jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)', 'jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)'], kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %% [markdown]
# # profilisasi cluster jumlah_pengunjung_ke Objek Wisata_Mancanegara :
# 1. Cluster 0: jumlah pengunjung ke Objek Wisata Mancanegara tinggi
# 2. Cluster 1: jumlah pengunjung ke Objek Wisata Mancanegara sedang
# 3. Cluster 2: jumlah pengunjung ke Objek Wisata Mancanegara rendah
# # profilisasi cluster asing :
# 1. Cluster 0: jumlah_pengunjung_ke Objek Wisata_Nusantara tinggi
# 2. Cluster 1: jumlah_pengunjung_ke Objek Wisata_Nusantara rendah
# 3. Cluster 2: jjumlah_pengunjung_ke Objek Wisata_Nusantara sedang

# %%
profil.plot(x = 'cluster', y = ['jumlah_pengunjung _Kolam Renang_Mancanegara (X3)', 'jumlah_pengunjung _Kolam Renang_Nusantara (X4)'], kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
profil.plot(x = 'cluster', y = ['jumlah_pengunjung_Kawasan Pariwisata_Mancanegara (X5)', 'jumlah_pengunjung_Kawasan Pariwisata_Nusantara (X6)'], kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
profil.plot(x = 'cluster', y = ['kasus_aktif_jabar (X7)'], kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
# Anggota cluster 0
pariwisata_jabar[pariwisata_jabar.cluster == 0]
# Out:
#         nama_kabupaten_kota  \
# 0         KABUPATEN BANDUNG
# 1   KABUPATEN BANDUNG BARAT
# 3           KABUPATEN BOGOR
# 5         KABUPATEN CIANJUR
# 13     KABUPATEN PURWAKARTA
# 14         KABUPATEN SUBANG
# 18             KOTA BANDUNG
# 21               KOTA BOGOR
#
#     jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 0                                             1577118
# 1                                             1438382
# 3                                             1216875
# 5                                              509351
# 13                                             440020
# 14                                            1095227
# 18                                             924898
# 21                                             477800
#
#     jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# 0                                           25792956
# 1                                           27734199
# ...

# %%
pariwisata_jabar[pariwisata_jabar.cluster == 0].to_csv('pariwisata_jabar_cluster_0.csv')

# %%
# Anggota cluster 1
pariwisata_jabar[pariwisata_jabar.cluster == 1]
# Out:
#       nama_kabupaten_kota  jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 4        KABUPATEN CIAMIS                                               6607
# 7         KABUPATEN GARUT                                              21964
# 8     KABUPATEN INDRAMAYU                                                 59
# 9      KABUPATEN KARAWANG                                               2372
# 10     KABUPATEN KUNINGAN                                               1107
# 12  KABUPATEN PANGANDARAN                                              31780
# 15     KABUPATEN SUKABUMI                                             175049
# 16     KABUPATEN SUMEDANG                                              38740
# 17  KABUPATEN TASIKMALAYA                                              16369
# 23           KOTA CIREBON                                               6203
#
#     jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# 4                                            4371123
# ...

# %%
pariwisata_jabar[pariwisata_jabar.cluster == 1].to_csv('pariwisata_jabar_cluster_1.csv')

# %%
# Anggota cluster 2
pariwisata_jabar[pariwisata_jabar.cluster == 2]
# Out:
#      nama_kabupaten_kota  jumlah_pengunjung_ke Objek Wisata_Mancanegara (X1)  \
# 2       KABUPATEN BEKASI                                                  3
# 6      KABUPATEN CIREBON                                                 15
# 11  KABUPATEN MAJALENGKA                                               3058
# 19           KOTA BANJAR                                                 32
# 20           KOTA BEKASI                                                 30
# 22           KOTA CIMAHI                                               1699
# 24            KOTA DEPOK                                              24167
# 25         KOTA SUKABUMI                                              10468
# 26      KOTA TASIKMALAYA                                             267156
#
#     jumlah_pengunjung_ke Objek Wisata_Nusantara (X2)  \
# 2                                             383413
# 6                                            3841479
# ...

# %%
pariwisata_jabar[pariwisata_jabar.cluster == 2].to_csv('pariwisata_jabar_cluster_2.csv')
